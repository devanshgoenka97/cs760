# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.datasets as datasets
import imageio
import numpy as np
import matplotlib
from torchvision.utils import make_grid, save_image
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # Define learning parameters

# %%
# learning parameters
batch_size = 512
epochs = 100
sample_size = 64 # fixed sample size for generator
nz = 128 # latent vector size
k = 1 # number of steps to apply to the discriminator
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Prepare training dataset

# %%
transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,)),
])
to_pil_image = transforms.ToPILImage()

# Make input, output folders
# !mkdir -p input
# !mkdir -p outputs

# Load train data
train_data = datasets.MNIST(
    root='input/data',
    train=True,
    download=True,
    transform=transform
)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to input/data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting input/data/MNIST/raw/train-images-idx3-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to input/data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting input/data/MNIST/raw/train-labels-idx1-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to input/data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting input/data/MNIST/raw/t10k-images-idx3-ubyte.gz to input/data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to input/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting input/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to input/data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self, nz):
        super(Generator, self).__init__()
        self.nz = nz
        self.main = nn.Sequential(
            nn.Linear(self.nz, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh(),
        )
    def forward(self, x):
        return self.main(x).view(-1, 1, 28, 28)

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.n_input = 784
        self.main = nn.Sequential(
            nn.Linear(self.n_input, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
    def forward(self, x):
        x = x.view(-1, 784)
        return self.main(x)

# %%
generator = Generator(nz).to(device)
discriminator = Discriminator().to(device)
print('##### GENERATOR #####')
print(generator)
print('######################')
print('\n##### DISCRIMINATOR #####')
print(discriminator)
print('######################')
# Out:
# ##### GENERATOR #####
# Generator(
#   (main): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.2)
#     (6): Linear(in_features=1024, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )
# ######################
#
# ##### DISCRIMINATOR #####
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )
# ######################

# %% [markdown]
# # Tools for training

# %%
# optimizers
optim_g = optim.Adam(generator.parameters(), lr=0.0002)
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002)

# %%
# loss function
criterion = nn.BCELoss() # Binary Cross Entropy loss

# %%
losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator

# %%
# to create real labels (1s)
def label_real(size):
    data = torch.ones(size, 1)
    # Trying out near-ones instead of absolute ones
    # data = torch.sub(data, torch.tensor(0.1))
    return data.to(device)
# to create fake labels (0s)
def label_fake(size):
    data = torch.zeros(size, 1)
    return data.to(device)

# %%
# function to create the noise vector
def create_noise(sample_size, nz):
    return torch.randn(sample_size, nz).to(device)

# %%
# to save the images generated by the generator
def save_generator_image(image, path):
    save_image(image, path)

# %%
# create the noise vector - fixed to track how GAN is trained.
noise = create_noise(sample_size, nz)

# %% [markdown]
# # Q. Write training loop

# %%
torch.manual_seed(7777)

def generator_loss(output, true_label):
    return criterion(output, true_label)
    
def discriminator_loss(output, true_label):
    return criterion(output, true_label)
    

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):
        real_images, _ = data
        real_images = real_images.to(device)

        # Training the discriminator for 'k' steps
        for i in range(k):
           # Creating fake samples from generator to train the discriminator
           fake_images = generator(create_noise(sample_size, nz)).detach()
           fake_labels = label_fake(fake_images.shape[0])
           
           # Creating true labels for real images from dataset
           real_labels = label_real(real_images.shape[0])
           
           optim_d.zero_grad()

           # Generating first term of the loss from discriminator and backpropagating it
           real_output = discriminator(real_images)
           
           # Using Least Squares loss function
           real_loss = 0.5 * torch.mean((real_output-real_labels)**2) 
           
           # Generating second term of the loss from discriminator and backpropagating it
           fake_output = discriminator(fake_images)
    
           # Using Least Squares loss function
           fake_loss = 0.5 * torch.mean((fake_output-fake_labels)**2) 

           real_loss.backward()
           fake_loss.backward()

           optim_d.step()

           # Actual discriminator loss is the sum of both terms
           loss_d += real_loss + fake_loss

        # Training the generator for one step
        fake_images = generator(create_noise(sample_size, nz))
        real_labels = label_real(fake_images.shape[0])
        fake_labels = label_fake(fake_images.shape[0])

        optim_g.zero_grad()

        # Passing fake images through discriminator
        output = discriminator(fake_images)

        # Generating the loss for the generator
        # Using Least Squares loss function
        gen_loss = 0.5 * torch.mean((output-real_labels)**2) 

        gen_loss.backward()

        optim_g.step()

        loss_g += gen_loss
    
    
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    
    # make the images as grid
    generated_img = make_grid(generated_img)
    
    # visualize generated images
    if (epoch + 1) % 5 == 0:
        plt.imshow(generated_img.permute(1, 2, 0))
        plt.title(f'epoch {epoch+1}')
        plt.axis('off')
        plt.show()
    
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"outputs/gen_img{epoch+1}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch+1} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# 118it [00:16,  7.02it/s]
# Epoch 1 of 100
# Generator loss: 0.30007818, Discriminator loss: 0.10771527
# 118it [00:16,  7.05it/s]
# Epoch 2 of 100
# Generator loss: 0.46648252, Discriminator loss: 0.05537892
# 118it [00:16,  7.04it/s]
# Epoch 3 of 100
# Generator loss: 0.37688246, Discriminator loss: 0.13727020
# 118it [00:16,  7.00it/s]
# Epoch 4 of 100
# Generator loss: 0.46501002, Discriminator loss: 0.03903592
# 118it [00:16,  7.04it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 5 of 100
# Generator loss: 0.41672814, Discriminator loss: 0.10958253
# 118it [00:16,  6.99it/s]
# Epoch 6 of 100
# Generator loss: 0.46673593, Discriminator loss: 0.07399394
# 118it [00:16,  7.00it/s]
# Epoch 7 of 100
# Generator loss: 0.50394148, Discriminator loss: 0.00004764
# 118it [00:16,  7.01it/s]
# Epoch 8 of 100
# Generator loss: 0.48079452, Discriminator loss: 0.01743761
# 118it [00:16,  6.97it/s]
# Epoch 9 of 100
# Generator loss: 0.34137714, Discriminator loss: 0.14241101
# 118it [00:17,  6.91it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 10 of 100
# Generator loss: 0.33183134, Discriminator loss: 0.16002437
# 118it [00:17,  6.93it/s]
# Epoch 11 of 100
# Generator loss: 0.46130195, Discriminator loss: 0.03897661
# 118it [00:16,  6.96it/s]
# Epoch 12 of 100
# Generator loss: 0.40380317, Discriminator loss: 0.08570212
# 118it [00:16,  6.99it/s]
# Epoch 13 of 100
# Generator loss: 0.36259899, Discriminator loss: 0.13666101
# 118it [00:16,  7.03it/s]
# Epoch 14 of 100
# Generator loss: 0.30900952, Discriminator loss: 0.17426500
# 118it [00:16,  7.04it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 15 of 100
# Generator loss: 0.37278518, Discriminator loss: 0.10506901
# 118it [00:17,  6.93it/s]
# Epoch 16 of 100
# Generator loss: 0.25693747, Discriminator loss: 0.20340046
# 118it [00:16,  6.97it/s]
# Epoch 17 of 100
# Generator loss: 0.27529976, Discriminator loss: 0.18475275
# 118it [00:16,  6.95it/s]
# Epoch 18 of 100
# Generator loss: 0.18820734, Discriminator loss: 0.23991629
# 118it [00:17,  6.92it/s]
# Epoch 19 of 100
# Generator loss: 0.25136253, Discriminator loss: 0.19086842
# 118it [00:17,  6.88it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 20 of 100
# Generator loss: 0.35476947, Discriminator loss: 0.11610170
# 118it [00:17,  6.90it/s]
# Epoch 21 of 100
# Generator loss: 0.38618365, Discriminator loss: 0.11370164
# 118it [00:17,  6.89it/s]
# Epoch 22 of 100
# Generator loss: 0.33907056, Discriminator loss: 0.14845811
# 118it [00:17,  6.90it/s]
# Epoch 23 of 100
# Generator loss: 0.36427274, Discriminator loss: 0.11268115
# 118it [00:17,  6.90it/s]
# Epoch 24 of 100
# Generator loss: 0.42312628, Discriminator loss: 0.06657059
# 118it [00:17,  6.92it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 25 of 100
# Generator loss: 0.42872638, Discriminator loss: 0.07169804
# 118it [00:17,  6.86it/s]
# Epoch 26 of 100
# Generator loss: 0.41516271, Discriminator loss: 0.10617866
# 118it [00:17,  6.85it/s]
# Epoch 27 of 100
# Generator loss: 0.35748523, Discriminator loss: 0.14263028
# 118it [00:17,  6.77it/s]
# Epoch 28 of 100
# Generator loss: 0.38581550, Discriminator loss: 0.11930995
# 118it [00:17,  6.87it/s]
# Epoch 29 of 100
# Generator loss: 0.37168142, Discriminator loss: 0.11910906
# 118it [00:17,  6.87it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 30 of 100
# Generator loss: 0.40935063, Discriminator loss: 0.07654930
# 118it [00:17,  6.82it/s]
# Epoch 31 of 100
# Generator loss: 0.38304046, Discriminator loss: 0.10576953
# 118it [00:17,  6.82it/s]
# Epoch 32 of 100
# Generator loss: 0.38268846, Discriminator loss: 0.12376980
# 118it [00:17,  6.83it/s]
# Epoch 33 of 100
# Generator loss: 0.36530885, Discriminator loss: 0.12219510
# 118it [00:17,  6.84it/s]
# Epoch 34 of 100
# Generator loss: 0.33176619, Discriminator loss: 0.14056741
# 118it [00:17,  6.83it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 35 of 100
# Generator loss: 0.34836969, Discriminator loss: 0.12799650
# 118it [00:17,  6.79it/s]
# Epoch 36 of 100
# Generator loss: 0.35593116, Discriminator loss: 0.11619105
# 118it [00:17,  6.78it/s]
# Epoch 37 of 100
# Generator loss: 0.37217700, Discriminator loss: 0.10900646
# 118it [00:17,  6.80it/s]
# Epoch 38 of 100
# Generator loss: 0.36454225, Discriminator loss: 0.11012733
# 118it [00:17,  6.81it/s]
# Epoch 39 of 100
# Generator loss: 0.37507492, Discriminator loss: 0.10715680
# 118it [00:17,  6.79it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 40 of 100
# Generator loss: 0.35371694, Discriminator loss: 0.14281186
# 118it [00:17,  6.70it/s]
# Epoch 41 of 100
# Generator loss: 0.34323621, Discriminator loss: 0.13320470
# 118it [00:17,  6.75it/s]
# Epoch 42 of 100
# Generator loss: 0.33874083, Discriminator loss: 0.12632798
# 118it [00:17,  6.79it/s]
# Epoch 43 of 100
# Generator loss: 0.35679018, Discriminator loss: 0.11257943
# 118it [00:17,  6.78it/s]
# Epoch 44 of 100
# Generator loss: 0.33500275, Discriminator loss: 0.13191691
# 118it [00:17,  6.76it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 45 of 100
# Generator loss: 0.35618755, Discriminator loss: 0.10814889
# 118it [00:17,  6.68it/s]
# Epoch 46 of 100
# Generator loss: 0.35987711, Discriminator loss: 0.13030329
# 118it [00:17,  6.66it/s]
# Epoch 47 of 100
# Generator loss: 0.36236545, Discriminator loss: 0.11110777
# 118it [00:17,  6.75it/s]
# Epoch 48 of 100
# Generator loss: 0.36931697, Discriminator loss: 0.10430972
# 118it [00:17,  6.74it/s]
# Epoch 49 of 100
# Generator loss: 0.34292421, Discriminator loss: 0.12696542
# 118it [00:17,  6.77it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 50 of 100
# Generator loss: 0.32552043, Discriminator loss: 0.15053682
# 118it [00:17,  6.76it/s]
# Epoch 51 of 100
# Generator loss: 0.34848461, Discriminator loss: 0.12126740
# 118it [00:17,  6.80it/s]
# Epoch 52 of 100
# Generator loss: 0.35774684, Discriminator loss: 0.10897390
# 118it [00:17,  6.72it/s]
# Epoch 53 of 100
# Generator loss: 0.34966549, Discriminator loss: 0.12244770
# 118it [00:17,  6.73it/s]
# Epoch 54 of 100
# Generator loss: 0.35969660, Discriminator loss: 0.11223746
# 118it [00:17,  6.71it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 55 of 100
# Generator loss: 0.34118056, Discriminator loss: 0.12744887
# 118it [00:17,  6.74it/s]
# Epoch 56 of 100
# Generator loss: 0.33942920, Discriminator loss: 0.12694229
# 118it [00:17,  6.83it/s]
# Epoch 57 of 100
# Generator loss: 0.32946160, Discriminator loss: 0.13090703
# 118it [00:17,  6.75it/s]
# Epoch 58 of 100
# Generator loss: 0.34290493, Discriminator loss: 0.12481377
# 118it [00:17,  6.76it/s]
# Epoch 59 of 100
# Generator loss: 0.35678083, Discriminator loss: 0.11226454
# 118it [00:17,  6.75it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 60 of 100
# Generator loss: 0.33061022, Discriminator loss: 0.12988570
# 118it [00:17,  6.73it/s]
# Epoch 61 of 100
# Generator loss: 0.33964118, Discriminator loss: 0.12728435
# 118it [00:17,  6.76it/s]
# Epoch 62 of 100
# Generator loss: 0.34313902, Discriminator loss: 0.12430297
# 118it [00:17,  6.69it/s]
# Epoch 63 of 100
# Generator loss: 0.31561655, Discriminator loss: 0.14208435
# 118it [00:17,  6.70it/s]
# Epoch 64 of 100
# Generator loss: 0.31418660, Discriminator loss: 0.13802066
# 118it [00:17,  6.73it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 65 of 100
# Generator loss: 0.34898666, Discriminator loss: 0.12398972
# 118it [00:17,  6.70it/s]
# Epoch 66 of 100
# Generator loss: 0.33133498, Discriminator loss: 0.13502544
# 118it [00:17,  6.68it/s]
# Epoch 67 of 100
# Generator loss: 0.36316583, Discriminator loss: 0.10402087
# 118it [00:17,  6.81it/s]
# Epoch 68 of 100
# Generator loss: 0.35109904, Discriminator loss: 0.10568148
# 118it [00:17,  6.79it/s]
# Epoch 69 of 100
# Generator loss: 0.32516563, Discriminator loss: 0.12897192
# 118it [00:17,  6.80it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 70 of 100
# Generator loss: 0.33063903, Discriminator loss: 0.13368136
# 118it [00:17,  6.68it/s]
# Epoch 71 of 100
# Generator loss: 0.31690976, Discriminator loss: 0.14094810
# 118it [00:17,  6.71it/s]
# Epoch 72 of 100
# Generator loss: 0.32798511, Discriminator loss: 0.12608214
# 118it [00:17,  6.67it/s]
# Epoch 73 of 100
# Generator loss: 0.34416029, Discriminator loss: 0.11987352
# 118it [00:17,  6.69it/s]
# Epoch 74 of 100
# Generator loss: 0.33941007, Discriminator loss: 0.12738012
# 118it [00:17,  6.70it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 75 of 100
# Generator loss: 0.31649071, Discriminator loss: 0.14224942
# 118it [00:17,  6.66it/s]
# Epoch 76 of 100
# Generator loss: 0.32988697, Discriminator loss: 0.11912127
# 118it [00:17,  6.74it/s]
# Epoch 77 of 100
# Generator loss: 0.33501703, Discriminator loss: 0.11715768
# 118it [00:17,  6.70it/s]
# Epoch 78 of 100
# Generator loss: 0.32089931, Discriminator loss: 0.13117775
# 118it [00:17,  6.69it/s]
# Epoch 79 of 100
# Generator loss: 0.32690963, Discriminator loss: 0.13367824
# 118it [00:17,  6.68it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 80 of 100
# Generator loss: 0.30481705, Discriminator loss: 0.14959566
# 118it [00:17,  6.68it/s]
# Epoch 81 of 100
# Generator loss: 0.30534837, Discriminator loss: 0.13809769
# 118it [00:17,  6.66it/s]
# Epoch 82 of 100
# Generator loss: 0.31345049, Discriminator loss: 0.13824911
# 118it [00:17,  6.71it/s]
# Epoch 83 of 100
# Generator loss: 0.31664744, Discriminator loss: 0.13490276
# 118it [00:17,  6.63it/s]
# Epoch 84 of 100
# Generator loss: 0.31843328, Discriminator loss: 0.14006795
# 118it [00:17,  6.66it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 85 of 100
# Generator loss: 0.31235456, Discriminator loss: 0.13668831
# 118it [00:17,  6.65it/s]
# Epoch 86 of 100
# Generator loss: 0.32843602, Discriminator loss: 0.12169985
# 118it [00:17,  6.66it/s]
# Epoch 87 of 100
# Generator loss: 0.31566426, Discriminator loss: 0.13619648
# 118it [00:17,  6.64it/s]
# Epoch 88 of 100
# Generator loss: 0.31003547, Discriminator loss: 0.14791891
# 118it [00:17,  6.67it/s]
# Epoch 89 of 100
# Generator loss: 0.30318394, Discriminator loss: 0.14493217
# 118it [00:17,  6.66it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 90 of 100
# Generator loss: 0.29751116, Discriminator loss: 0.14731640
# 118it [00:17,  6.61it/s]
# Epoch 91 of 100
# Generator loss: 0.30659315, Discriminator loss: 0.13229486
# 118it [00:17,  6.64it/s]
# Epoch 92 of 100
# Generator loss: 0.31536597, Discriminator loss: 0.13310233
# 118it [00:17,  6.68it/s]
# Epoch 93 of 100
# Generator loss: 0.32039264, Discriminator loss: 0.13490316
# 118it [00:17,  6.58it/s]
# Epoch 94 of 100
# Generator loss: 0.29914111, Discriminator loss: 0.14456402
# 118it [00:17,  6.66it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 95 of 100
# Generator loss: 0.29499418, Discriminator loss: 0.14553946
# 118it [00:17,  6.65it/s]
# Epoch 96 of 100
# Generator loss: 0.28841206, Discriminator loss: 0.14886120
# 118it [00:17,  6.66it/s]
# Epoch 97 of 100
# Generator loss: 0.29261479, Discriminator loss: 0.14736500
# 118it [00:17,  6.68it/s]
# Epoch 98 of 100
# Generator loss: 0.29770264, Discriminator loss: 0.14914566
# 118it [00:17,  6.66it/s]
# Epoch 99 of 100
# Generator loss: 0.28621322, Discriminator loss: 0.15451184
# 118it [00:17,  6.59it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 100 of 100
# Generator loss: 0.29616883, Discriminator loss: 0.14522195

# %%
print('DONE TRAINING')
torch.save(generator.state_dict(), 'outputs/generator.pth')
# Out:
# DONE TRAINING

# %%
# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('outputs/generator_images.gif', imgs)

# %%
# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g, label='Generator loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.legend()
plt.savefig('outputs/loss.png')
